# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import librosa
import librosa.display

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score

import tensorflow as tf
from tensorflow.keras import layers, models
from keras.utils import to_categorical
import itertools

from sklearn.preprocessing import StandardScaler

import warnings
warnings.simplefilter('ignore')
# Out:
# D:\Anaconda3\envs\speech5p310\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
def convert_to_mel_spectrogram(file_path):
  y, sr = librosa.load(file_path, sr=None)

  # Convert to Mel spectrogram
  mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128)

  # Convert to log scale (dB)
  mel_spectrogram_db = librosa.power_to_db(mel_spectrogram, ref=np.max)
  return mel_spectrogram_db, sr

def plotting_mel_spectogram(spectrogram, sr):
  plt.figure(figsize=(10, 4))
  librosa.display.specshow(spectrogram, sr=sr, x_axis='time', y_axis='mel')
  plt.colorbar(format='%+2.0f dB')
  plt.title('Mel Spectrogram')
  plt.tight_layout()
  plt.show()

def get_spectrogram_plot(file_path):
  spectrogram, sr = convert_to_mel_spectrogram(file_path)
  plotting_mel_spectogram(spectrogram, sr)

# %%
import os
import librosa

directory_path = './wavfiles/'
files = os.listdir(directory_path)

for file in files:
    # Check if the file is a wav file
    if file.endswith('.wav'):
        get_spectrogram_plot(f"./wavfiles/{file}")
        break

def get_spectrogram_plot(file_path):
    spectrogram, sr = convert_to_mel_spectrogram(file_path)
    plotting_mel_spectogram(spectrogram, sr)

def convert_to_mel_spectrogram(file_path):
    y, sr = librosa.load(file_path, sr=None)
    # Convert to Mel spectrogram
    mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128)
    return mel_spectrogram, sr

def plotting_mel_spectogram(spectrogram, sr):
    # Add your plotting code here
    pass

# %%
metadata = pd.read_csv("./bird_songs_metadata.csv")

# %%
metadata.shape
# Out:
# (5422, 18)

# %%
metadata.head(10)
# Out:
#        id       genus   species subspecies           name  \
# 0  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 1  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 2  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 3  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 4  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 5  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 6  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 7  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 8  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 9  557838  Thryomanes  bewickii        NaN  Bewick's Wren
#
#                 recordist        country  \
# 0  Whitney Neufeld-Kaiser  United States
# 1  Whitney Neufeld-Kaiser  United States
# 2  Whitney Neufeld-Kaiser  United States
# 3  Whitney Neufeld-Kaiser  United States
# 4  Whitney Neufeld-Kaiser  United States
# 5  Whitney Neufeld-Kaiser  United States
# 6  Whitney Neufeld-Kaiser  United States
# 7  Whitney Neufeld-Kaiser  United States
# 8  Whitney Neufeld-Kaiser  United States
# 9  Whitney Neufeld-Kaiser  United States
#
#                                   location  latitude  longitude altitude  \
# 0  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 1  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 2  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 3  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 4  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 5  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 6  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 7  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 8  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 9  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
#
#                    sound_type                   source_url  \
# 0  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 1  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 2  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 3  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 4  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 5  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 6  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 7  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 8  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 9  adult, sex uncertain, song  //www.xeno-canto.org/557838
#
#                                         license   time        date  \
# 0  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 1  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 2  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 3  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 4  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 5  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 6  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 7  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 8  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 9  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
#
#                                              remarks       filename
# 0  Recorded with Voice Record Pro on iPhone7, nor...   557838-0.wav
# 1  Recorded with Voice Record Pro on iPhone7, nor...   557838-1.wav
# 2  Recorded with Voice Record Pro on iPhone7, nor...   557838-4.wav
# 3  Recorded with Voice Record Pro on iPhone7, nor...   557838-5.wav
# 4  Recorded with Voice Record Pro on iPhone7, nor...   557838-6.wav
# 5  Recorded with Voice Record Pro on iPhone7, nor...   557838-8.wav
# 6  Recorded with Voice Record Pro on iPhone7, nor...   557838-9.wav
# 7  Recorded with Voice Record Pro on iPhone7, nor...  557838-11.wav
# 8  Recorded with Voice Record Pro on iPhone7, nor...  557838-14.wav
# 9  Recorded with Voice Record Pro on iPhone7, nor...  557838-15.wav

# %%
librosa_audio_data, librosa_sample_rate = librosa.load('./wavfiles/11713-1.wav')
print(librosa_audio_data)
print(librosa_sample_rate)
# Out:
# [ 0.15442057 -0.2753804  -0.5479337  ...  0.06947865  0.03835445
#  -0.06795005]
# 22050

# %%
librosa_audio_data.shape
# Out:
# (66150,)

# %%
plt.figure(figsize=(10,4))
plt.plot(librosa_audio_data)

# %%
mfccs = librosa.feature.mfcc(y=librosa_audio_data, sr=librosa_sample_rate, n_mfcc = 39)
mfccs.shape
# Out:
# (39, 130)

# %%
def get_mfcc_features(file_path):
  y, sr = librosa.load(file_path)
  mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=39)
  scaled_features = np.mean(mfccs.T, axis=0)
  return scaled_features

# %%
from tqdm import tqdm

features_and_labels = []
for index, row in tqdm(metadata.iterrows(), total=metadata.shape[0]):
    file_name = "./wavfiles/" + row['filename']
    labels = row['name']
    scaled_features_each = get_mfcc_features(file_name)
    features_and_labels.append([scaled_features_each, labels])
# Out:
# 100%|██████████| 5422/5422 [00:28<00:00, 188.56it/s]

# %%
features_and_labels_df = pd.DataFrame(features_and_labels, columns=['features', 'labels'])
features_and_labels_df
# Out:
#                                                features             labels
# 0     [-132.85225, 81.1399, 17.018225, 54.974297, -1...      Bewick's Wren
# 1     [-147.74393, 99.42544, 20.885643, 44.11881, 1....      Bewick's Wren
# 2     [-92.42778, 84.10635, 17.362778, 53.86046, -8....      Bewick's Wren
# 3     [-93.07557, 81.17431, 16.225544, 52.08842, -8....      Bewick's Wren
# 4     [-107.95914, 92.416, 17.773256, 43.13245, -1.8...      Bewick's Wren
# ...                                                 ...                ...
# 5417  [-265.4909, 25.234486, -71.860214, 21.496227, ...  Northern Cardinal
# 5418  [-229.15498, 6.058426, -86.364815, 31.295118, ...  Northern Cardinal
# 5419  [-228.50348, 9.504912, -82.23682, 27.831066, 7...  Northern Cardinal
# 5420  [-222.64116, 13.23448, -77.96408, 26.501926, 1...  Northern Cardinal
# 5421  [-256.7084, 39.117977, -70.26597, 16.503796, 1...  Northern Cardinal
#
# [5422 rows x 2 columns]

# %%
X = np.array(features_and_labels_df['features'].tolist())
Y = np.array(features_and_labels_df['labels'].tolist())

# %%
print(X.shape)
print(Y.shape)
# Out:
# (5422, 39)
# (5422,)

# %%
y = np.array(pd.get_dummies(Y))
y = y.astype(int)

# %%
def get_species_name(output_array, main_array=y):
    for i in range(len(main_array)):
        if np.array_equal(main_array[i], output_array):
            return Y[i]
    return None

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from keras.regularizers import l2
from keras.callbacks import ReduceLROnPlateau



X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = Sequential([
    Dense(1024, activation='relu', input_shape=(X_train.shape[1],), kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.5),
    
    Dense(1024, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.5),
    
    Dense(512, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.5),
    
    Dense(512, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.5),
    
    Dense(256, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.5),
    
    Dense(256, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.5),
    
    Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.5),
    
    Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.5),
    
    Dense(64, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.5),
    
    Dense(64, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.5),
    
    Dense(y_train.shape[1], activation='softmax')
])

# %%
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_33 (Dense)            (None, 1024)              40960
#
#  batch_normalization_30 (Bat  (None, 1024)             4096
#  chNormalization)
#
#  dropout_30 (Dropout)        (None, 1024)              0
#
#  dense_34 (Dense)            (None, 1024)              1049600
#
#  batch_normalization_31 (Bat  (None, 1024)             4096
#  chNormalization)
#
#  dropout_31 (Dropout)        (None, 1024)              0
#
#  dense_35 (Dense)            (None, 512)               524800
#
#  batch_normalization_32 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dropout_32 (Dropout)        (None, 512)               0
#
#  dense_36 (Dense)            (None, 512)               262656
#
#  batch_normalization_33 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dropout_33 (Dropout)        (None, 512)               0
#
#  dense_37 (Dense)            (None, 256)               131328
#
#  batch_normalization_34 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_34 (Dropout)        (None, 256)               0
#
#  dense_38 (Dense)            (None, 256)               65792
#
#  batch_normalization_35 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_35 (Dropout)        (None, 256)               0
#
#  dense_39 (Dense)            (None, 128)               32896
#
#  batch_normalization_36 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_36 (Dropout)        (None, 128)               0
#
#  dense_40 (Dense)            (None, 128)               16512
#
#  batch_normalization_37 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_37 (Dropout)        (None, 128)               0
#
#  dense_41 (Dense)            (None, 64)                8256
#
#  batch_normalization_38 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_38 (Dropout)        (None, 64)                0
#
#  dense_42 (Dense)            (None, 64)                4160
#
#  batch_normalization_39 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_39 (Dropout)        (None, 64)                0
#
#  dense_43 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 2,153,157
# Trainable params: 2,145,221
# Non-trainable params: 7,936
# _________________________________________________________________

# %%
lr_reduction = ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5, min_lr=0.00001)

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, callbacks=[lr_reduction])
# Out:
# Epoch 1/50
# 109/109 [==============================] - 2s 15ms/step - loss: 0.2300 - accuracy: 0.9939 - val_loss: 0.3975 - val_accuracy: 0.9654 - lr: 1.0000e-05
# Epoch 2/50
# 109/109 [==============================] - 2s 15ms/step - loss: 0.2318 - accuracy: 0.9925 - val_loss: 0.4003 - val_accuracy: 0.9643 - lr: 1.0000e-05
# Epoch 3/50
# 109/109 [==============================] - 2s 15ms/step - loss: 0.2354 - accuracy: 0.9914 - val_loss: 0.3898 - val_accuracy: 0.9643 - lr: 1.0000e-05
# Epoch 4/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2252 - accuracy: 0.9934 - val_loss: 0.3956 - val_accuracy: 0.9654 - lr: 1.0000e-05
# Epoch 5/50
# 109/109 [==============================] - 2s 15ms/step - loss: 0.2206 - accuracy: 0.9954 - val_loss: 0.3984 - val_accuracy: 0.9654 - lr: 1.0000e-05
# Epoch 6/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2304 - accuracy: 0.9931 - val_loss: 0.3996 - val_accuracy: 0.9631 - lr: 1.0000e-05
# Epoch 7/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2280 - accuracy: 0.9925 - val_loss: 0.3983 - val_accuracy: 0.9631 - lr: 1.0000e-05
# Epoch 8/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2184 - accuracy: 0.9951 - val_loss: 0.3956 - val_accuracy: 0.9608 - lr: 1.0000e-05
# Epoch 9/50
# 109/109 [==============================] - 2s 15ms/step - loss: 0.2363 - accuracy: 0.9905 - val_loss: 0.3949 - val_accuracy: 0.9597 - lr: 1.0000e-05
# Epoch 10/50
# 109/109 [==============================] - 2s 16ms/step - loss: 0.2361 - accuracy: 0.9919 - val_loss: 0.3984 - val_accuracy: 0.9597 - lr: 1.0000e-05
# Epoch 11/50
# 109/109 [==============================] - 2s 15ms/step - loss: 0.2304 - accuracy: 0.9928 - val_loss: 0.3979 - val_accuracy: 0.9597 - lr: 1.0000e-05
# Epoch 12/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2357 - accuracy: 0.9902 - val_loss: 0.3956 - val_accuracy: 0.9620 - lr: 1.0000e-05
# Epoch 13/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2351 - accuracy: 0.9902 - val_loss: 0.3956 - val_accuracy: 0.9631 - lr: 1.0000e-05
# Epoch 14/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2284 - accuracy: 0.9939 - val_loss: 0.3982 - val_accuracy: 0.9631 - lr: 1.0000e-05
# Epoch 15/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2324 - accuracy: 0.9911 - val_loss: 0.3989 - val_accuracy: 0.9654 - lr: 1.0000e-05
# Epoch 16/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2372 - accuracy: 0.9908 - val_loss: 0.3959 - val_accuracy: 0.9631 - lr: 1.0000e-05
# Epoch 17/50
# 109/109 [==============================] - 2s 15ms/step - loss: 0.2240 - accuracy: 0.9916 - val_loss: 0.3956 - val_accuracy: 0.9643 - lr: 1.0000e-05
# Epoch 18/50
# 109/109 [==============================] - 2s 15ms/step - loss: 0.2237 - accuracy: 0.9928 - val_loss: 0.3973 - val_accuracy: 0.9631 - lr: 1.0000e-05
# Epoch 19/50
# 109/109 [==============================] - 2s 15ms/step - loss: 0.2254 - accuracy: 0.9942 - val_loss: 0.4016 - val_accuracy: 0.9643 - lr: 1.0000e-05
# Epoch 20/50
# 109/109 [==============================] - 2s 15ms/step - loss: 0.2389 - accuracy: 0.9893 - val_loss: 0.3948 - val_accuracy: 0.9643 - lr: 1.0000e-05
# Epoch 21/50
# 109/109 [==============================] - 2s 16ms/step - loss: 0.2269 - accuracy: 0.9931 - val_loss: 0.3945 - val_accuracy: 0.9631 - lr: 1.0000e-05
# Epoch 22/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2338 - accuracy: 0.9911 - val_loss: 0.3946 - val_accuracy: 0.9643 - lr: 1.0000e-05
# Epoch 23/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2347 - accuracy: 0.9919 - val_loss: 0.3933 - val_accuracy: 0.9643 - lr: 1.0000e-05
# Epoch 24/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2322 - accuracy: 0.9922 - val_loss: 0.4008 - val_accuracy: 0.9631 - lr: 1.0000e-05
# Epoch 25/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2337 - accuracy: 0.9942 - val_loss: 0.4024 - val_accuracy: 0.9620 - lr: 1.0000e-05
# Epoch 26/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2330 - accuracy: 0.9893 - val_loss: 0.4024 - val_accuracy: 0.9631 - lr: 1.0000e-05
# Epoch 27/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2213 - accuracy: 0.9954 - val_loss: 0.4004 - val_accuracy: 0.9620 - lr: 1.0000e-05
# Epoch 28/50
# 109/109 [==============================] - 2s 15ms/step - loss: 0.2252 - accuracy: 0.9939 - val_loss: 0.4018 - val_accuracy: 0.9643 - lr: 1.0000e-05
# Epoch 29/50
# 109/109 [==============================] - 2s 17ms/step - loss: 0.2265 - accuracy: 0.9925 - val_loss: 0.4031 - val_accuracy: 0.9654 - lr: 1.0000e-05
# Epoch 30/50
# 109/109 [==============================] - 2s 15ms/step - loss: 0.2196 - accuracy: 0.9939 - val_loss: 0.3989 - val_accuracy: 0.9643 - lr: 1.0000e-05
# Epoch 31/50
# 109/109 [==============================] - 2s 15ms/step - loss: 0.2294 - accuracy: 0.9914 - val_loss: 0.3973 - val_accuracy: 0.9643 - lr: 1.0000e-05
# Epoch 32/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2294 - accuracy: 0.9919 - val_loss: 0.3960 - val_accuracy: 0.9654 - lr: 1.0000e-05
# Epoch 33/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2225 - accuracy: 0.9928 - val_loss: 0.4026 - val_accuracy: 0.9643 - lr: 1.0000e-05
# Epoch 34/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2315 - accuracy: 0.9916 - val_loss: 0.3987 - val_accuracy: 0.9620 - lr: 1.0000e-05
# Epoch 35/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2175 - accuracy: 0.9942 - val_loss: 0.3966 - val_accuracy: 0.9631 - lr: 1.0000e-05
# Epoch 36/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2211 - accuracy: 0.9931 - val_loss: 0.4040 - val_accuracy: 0.9620 - lr: 1.0000e-05
# Epoch 37/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2359 - accuracy: 0.9902 - val_loss: 0.4007 - val_accuracy: 0.9643 - lr: 1.0000e-05
# Epoch 38/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2262 - accuracy: 0.9899 - val_loss: 0.4013 - val_accuracy: 0.9643 - lr: 1.0000e-05
# Epoch 39/50
# 109/109 [==============================] - 2s 15ms/step - loss: 0.2337 - accuracy: 0.9928 - val_loss: 0.4021 - val_accuracy: 0.9643 - lr: 1.0000e-05
# Epoch 40/50
# 109/109 [==============================] - 2s 15ms/step - loss: 0.2370 - accuracy: 0.9896 - val_loss: 0.4085 - val_accuracy: 0.9620 - lr: 1.0000e-05
# Epoch 41/50
# 109/109 [==============================] - 2s 17ms/step - loss: 0.2383 - accuracy: 0.9916 - val_loss: 0.3992 - val_accuracy: 0.9597 - lr: 1.0000e-05
# Epoch 42/50
# 109/109 [==============================] - 2s 15ms/step - loss: 0.2199 - accuracy: 0.9928 - val_loss: 0.3983 - val_accuracy: 0.9620 - lr: 1.0000e-05
# Epoch 43/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2200 - accuracy: 0.9937 - val_loss: 0.3959 - val_accuracy: 0.9643 - lr: 1.0000e-05
# Epoch 44/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2283 - accuracy: 0.9934 - val_loss: 0.3962 - val_accuracy: 0.9631 - lr: 1.0000e-05
# Epoch 45/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2252 - accuracy: 0.9928 - val_loss: 0.3980 - val_accuracy: 0.9643 - lr: 1.0000e-05
# Epoch 46/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2344 - accuracy: 0.9914 - val_loss: 0.3984 - val_accuracy: 0.9643 - lr: 1.0000e-05
# Epoch 47/50
# 109/109 [==============================] - 2s 15ms/step - loss: 0.2109 - accuracy: 0.9960 - val_loss: 0.3997 - val_accuracy: 0.9643 - lr: 1.0000e-05
# Epoch 48/50
# 109/109 [==============================] - 2s 14ms/step - loss: 0.2165 - accuracy: 0.9948 - val_loss: 0.4006 - val_accuracy: 0.9631 - lr: 1.0000e-05
# Epoch 49/50
# 109/109 [==============================] - 2s 15ms/step - loss: 0.2346 - accuracy: 0.9925 - val_loss: 0.4016 - val_accuracy: 0.9643 - lr: 1.0000e-05
# Epoch 50/50
# 109/109 [==============================] - 2s 15ms/step - loss: 0.2136 - accuracy: 0.9945 - val_loss: 0.4006 - val_accuracy: 0.9620 - lr: 1.0000e-05

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}')

print(f'Test Accuracy: {accuracy}')
# Out:
# 34/34 [==============================] - 0s 3ms/step - loss: 0.2856 - accuracy: 0.9797
# Test Loss: 0.28563392162323
# Test Accuracy: 0.9797235131263733

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
